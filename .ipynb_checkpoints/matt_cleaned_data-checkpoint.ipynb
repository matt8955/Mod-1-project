# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Minna Fingerhood
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Fangfang
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
#how does date affect the price of houses?
#heatmap of lat/long at house prices?
#how does bathroom and square footage -- high correlation demonstrated by heatmap

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# assingment:
#     - You'll clean, explore, and model this dataset with a multivariate linear regression to predict the sale price of houses as accurately as possible.
#
# questions to keep in mind:
#
#     -"how did you pick the question(s) that you did?"
#     -"why are these questions important from a business perspective?"
#     -"how did you decide on the data cleaning options you performed?"
#     -"why did you choose a given method or library?"
#     -"why did you select those visualizations and what did you learn from each of them?"
#     -"why did you pick those features as predictors?"
#     -"how would you interpret the results?"
#     -"how confident are you in the predictive quality of the results?"
#     -"what are some of the things that could cause the results to be wrong?"

# %%
#import data and packages
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt 
import statsmodels.formula.api as smf
import sklearn as sk
# %matplotlib inline
sns.set()

# %%
import functions as f

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#merge cristina datetime
df.date
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
# 5         5/12/2014
# 6         6/27/2014
# 7         1/15/2015
# 8         4/15/2015
# 9         3/12/2015
# 10         4/3/2015
# 11        5/27/2014
# 12        5/28/2014
# 13        10/7/2014
# 14        3/12/2015
# 15        1/24/2015
# 16        7/31/2014
# 17        5/29/2014
# 18        12/5/2014
# 19        4/24/2015
# 20        5/14/2014
# 21        8/26/2014
# 22         7/3/2014
# 23        5/16/2014
# 24       11/20/2014
# 25        11/3/2014
# 26        6/26/2014
# 27        12/1/2014
# 28        6/24/2014
# 29         3/2/2015
#             ...
# 21567     6/10/2014
# 21568     12/2/2014
# 21569     8/28/2014
# 21570    10/15/2014
# 21571      3/5/2015
# 21572    11/13/2014
# 21573     9/10/2014
# 21574     5/14/2014
# 21575     10/2/2014
# 21576     4/16/2015
# 21577     3/17/2015
# 21578    10/17/2014
# 21579    10/31/2014
# 21580     8/13/2014
# 21581     4/21/2015
# 21582    10/13/2014
# 21583     9/15/2014
# 21584    10/15/2014
# 21585      4/7/2015
# 21586     6/26/2014
# 21587     8/25/2014
# 21588     1/26/2015
# 21589    10/14/2014
# 21590     3/26/2015
# 21591     2/19/2015
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
#check & inspect duplicates id
df[df.id.duplicated(keep=False)]
#duplicates are a result of the same house being sold another time... Therefore do not need to delete
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535   7/25/2014   430000.0         3       1.50         1580
# 94     6021501535  12/23/2014   700000.0         3       1.50         1580
# 313    4139480200   6/18/2014  1380000.0         4       3.25         4290
# 314    4139480200   12/9/2014  1400000.0         4       3.25         4290
# 324    7520000520    9/5/2014   232000.0         2       1.00         1240
# 325    7520000520   3/11/2015   240500.0         2       1.00         1240
# 345    3969300030   7/23/2014   165000.0         4       1.00         1000
# 346    3969300030  12/29/2014   239900.0         4       1.00         1000
# 371    2231500030   10/1/2014   315000.0         4       2.25         2180
qft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 93         5000     1.0         0.0   0.0  ...      8        1290
# 94         5000     1.0         0.0   0.0  ...      8        1290
# 313       12103     1.0         0.0   3.0  ...     11        2690
# 314       12103     1.0         0.0   3.0  ...     11        2690
# 324       12092     1.0         NaN   0.0  ...      6         960
# 325       12092     1.0         0.0   0.0  ...      6         960
# 345        7134     1.0         0.0   0.0  ...      6        1000
# 346        7134     1.0         0.0   0.0  ...      6        1000
# 371       10754     1.0         NaN   0.0  ...      7        1100
# 372       10754     1.0         0.0   0.0  ...      7        1100
# 717       13579     2.0         0.0   0.0  ...      7        2660
# 718       13579     2.0         0.0   0.0  ...      7        2660
# 823        7200     1.0         0.0   0.0  ...      7        1130
# 824        7200     1.0         NaN   0.0  ...      7        1130
# 836        4003     1.0         0.0   0.0  ...      8        1350
# 837        4003     1.0         0.0   0.0  ...      8        1350
# 1084       4080     1.0         0.0   0.0  ...      7        1040
# 1085       4080     1.0         0.0   0.0  ...      7        1040
# 1127       6300     1.0         0.0   0.0  ...      7        1560
# 1128       6300     1.0         0.0   0.0  ...      7        1560
# 1200       3800     1.0         0.0   0.0  ...      6         700
# 1201       3800     1.0         0.0   0.0  ...      6         700
# 1232      11234     1.0         0.0   0.0  ...      6         790
# 1233      11234     1.0         0.0   0.0  ...      6         790
# 1448       6000     1.0         0.0   0.0  ...      6        1010
# 1449       6000     1.0         NaN   0.0  ...      6        1010
# 1462       5283     2.0         0.0   0.0  ...      9        3190
# 1463       5283     2.0         0.0   0.0  ...      9        3190
# 1574       7473     1.0         0.0   0.0  ...      7        1060
# 1575       7473     1.0         0.0   0.0  ...      7        1060
# ...         ...     ...         ...   ...  ...    ...         ...
# 18219      9030     1.0         0.0   0.0  ...      7        1520
# 18220      9030     1.0         0.0   0.0  ...      7        1520
# 18549      7980     1.5         0.0   0.0  ...      6        1220
# 18550      7980     1.5         0.0   0.0  ...      6        1220
# 18688     10080     1.0         0.0   0.0  ...      7        1390
# 18689     10080     1.0         0.0   0.0  ...      7        1390
# 18690      6180     1.5         0.0   0.0  ...      6        1600
# 18691      6180     1.5         0.0   0.0  ...      6        1600
# 18747      3740     1.5         0.0   0.0  ...      6        1330
# 18748      3740     1.5         NaN   0.0  ...      6        1330
# 18976      9400     2.0         0.0   4.0  ...     10        2610
# 18977      9400     2.0         0.0   4.0  ...     10        2610
# 19194      6654     1.5         0.0   0.0  ...      7        1940
# 19195      6654     1.5         NaN   0.0  ...      7        1940
# 19320      4000     1.0         0.0   0.0  ...      7        1080
# 19321      4000     1.0         0.0   0.0  ...      7        1080
# 19536      9500     1.0         0.0   0.0  ...      7        1470
# 19537      9500     1.0         0.0   0.0  ...      7        1470
# 20037      3211     2.0         0.0   0.0  ...      8        1940
# 20038      3211     2.0         0.0   0.0  ...      8        1940
# 20164      5260     2.0         0.0   0.0  ...      9        2910
# 20165      5260     2.0         0.0   0.0  ...      9        2910
# 20596      1092     2.0         NaN   0.0  ...      7         990
# 20597      1092     2.0         0.0   0.0  ...      7         990
# 20653      5539     2.0         0.0   0.0  ...      8        2680
# 20654      5539     2.0         NaN   0.0  ...      8        2680
# 20763      2171     1.5         0.0   0.0  ...      7        1200
# 20764      2171     1.5         0.0   0.0  ...      7        1200
# 21564      6000     2.0         0.0   0.0  ...      9        2780
# 20653            0.0     2013           0.0    98045  47.4759 -121.734
# 20654            0.0     2013           0.0    98045  47.4759 -121.734
# 20763            0.0     1933           0.0    98133  47.7076 -122.342
# 20764            0.0     1933           0.0    98133  47.7076 -122.342
# 21564            0.0     2013           0.0    98065  47.5184 -121.886
# 21565            0.0     2013           NaN    98065  47.5184 -121.886
#
#        sqft_living15  sqft_lot15
# 93              1570        4500
# 94              1570        4500
# 313             3860       11244
# 314             3860       11244
# 324             1820        7460
# 325             1820        7460
# 345             1020        7138
# 346             1020        7138
# 371             1810        6929
# 372             1810        6929
# 717             1120        8242
# 718             1120        8242
# 823             1810        8100
# 824             1810        8100
# 836             1350        4479
# 837             1350        4479
# 1084            1340        4080
# 1085            1340        4080
# 1127            1380        6300
# 1128            1380        6300
# 1200            2180        4000
# 1201            2180        4000
# 1232            1930       11871
# 1233            1930       11871
# 1448            1610        7313
# 1449            1610        7313
# 1462            2950        5198
# 1463            2950        5198
# 1574            1320        7912
# 1575            1320        7912
# ...              ...         ...
# 18219           1470        8712
# 18220           1470        8712
# 18549           1210        7920
# 18550           1210        7920
# 18688           2110        8475
# 18689           2110        8475
# 18690           1410        6180
# 18691           1410        6180
# 18747           1330        5053
# 18748           1330        5053
# 18976           3760        9450
# 18977           3760        9450
# 19194           2300        9500
# 19195           2300        9500
# 19320           1530        4240
# 19321           1530        4240
# 19536           1820       10091
# 19537           1820       10091
# 20037           1880        3078
# 20038           1880        3078
# 20164           2910        5260
# 20165           2910        5260
# 20596           1330        1466
# 20597           1330        1466
# 20653           2680        5992
# 20654           2680        5992
# 20763           1130        1598
# 20764           1130        1598
# 21564           2850        6000
# 21565           2850        6000
#
# [353 rows x 21 columns]

# %%
#deal with nulls in year renovated
df['yr_renovated'].describe()
# Out:
# count    17755.000000
# mean        83.636778
# std        399.946414
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
df = f.clean_data(df)

# %%
#look at box plots to check cat data after cleaning

# %%
#look at distributions of data to see if transformations needed

# %% [markdown]
# normalize features with log transforms

# %%
c = ['price', 'sqft_above', 'sqft_basement', 'sqft_living', 'sqft_living15', 'sqft_lot', 'sqft_lot15']
df = f.log_transform(df, c)

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a233589b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2337cba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d641d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a216c9898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a234ee2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a20e147b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23c34080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23b0def0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23b0dbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a200de780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a201081d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23bb4da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a222530f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a21dd0588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23aac630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a229cf198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a20681eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23be1128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23d40860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1fbbdeb8>]],
#       dtype=object)

# %%
#identify outliers by looking at each indep var vs dep
f.scatter_one_vs_all(df,'log_price')
# Out:
# 0

# %%
# chhose bedroom and bathrooms to elim outliers
outliers = ['bedrooms', 'bathrooms','long']
df = f.remove_outliers(df, outliers)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id                   21597 non-null int64
# date                 21597 non-null object
# bedrooms             21067 non-null float64
# bathrooms            21036 non-null float64
# floors               21597 non-null float64
# waterfront           21597 non-null float64
# view                 21534 non-null float64
# condition            21597 non-null int64
# grade                21597 non-null int64
# yr_built             21597 non-null int64
# yr_renovated         744 non-null float64
# zipcode              21597 non-null int64
# lat                  21597 non-null float64
# long                 21342 non-null float64
# log_price            21597 non-null float64
# log_sqft_above       21597 non-null float64
# log_sqft_basement    21597 non-null float64
# log_sqft_living      21597 non-null float64
# log_sqft_living15    21597 non-null float64
# log_sqft_lot         21597 non-null float64
# log_sqft_lot15       21597 non-null float64
# dtypes: float64(15), int64(5), object(1)
# memory usage: 3.5+ MB

# %%
f.scatter_one_vs_all(df,'log_price')
# Out:
# 0

# %%
#check for colinearity
sns.heatmap(abs(df.corr()), cmap = 'BuPu', linewidths=.5)

# %%
df.corr()[abs(df.corr()>.75)]
# Out:
#                     id  bedrooms  bathrooms  floors  waterfront  view  \
# id                 1.0       NaN        NaN     NaN         NaN   NaN
# bedrooms           NaN       1.0        NaN     NaN         NaN   NaN
# bathrooms          NaN       NaN        1.0     NaN         NaN   NaN
# floors             NaN       NaN        NaN     1.0         NaN   NaN
# waterfront         NaN       NaN        NaN     NaN         1.0   NaN
# view               NaN       NaN        NaN     NaN         NaN   1.0
# condition          NaN       NaN        NaN     NaN         NaN   NaN
# grade              NaN       NaN        NaN     NaN         NaN   NaN
# yr_built           NaN       NaN        NaN     NaN         NaN   NaN
# yr_renovated       NaN       NaN        NaN     NaN         NaN   NaN
# zipcode            NaN       NaN        NaN     NaN         NaN   NaN
# lat                NaN       NaN        NaN     NaN         NaN   NaN
# long               NaN       NaN        NaN     NaN         NaN   NaN
# log_price          NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_above     NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_basement  NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_living    NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_living15  NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_lot       NaN       NaN        NaN     NaN         NaN   NaN
# log_sqft_lot15     NaN       NaN        NaN     NaN         NaN   NaN
#
#                    condition  grade  yr_built  yr_renovated  zipcode  lat  \
# id                       NaN    NaN       NaN           NaN      NaN  NaN
# bedrooms                 NaN    NaN       NaN           NaN      NaN  NaN
# bathrooms                NaN    NaN       NaN           NaN      NaN  NaN
# floors                   NaN    NaN       NaN           NaN      NaN  NaN
# waterfront               NaN    NaN       NaN           NaN      NaN  NaN
# view                     NaN    NaN       NaN           NaN      NaN  NaN
# condition                1.0    NaN       NaN           NaN      NaN  NaN
# grade                    NaN    1.0       NaN           NaN      NaN  NaN
# yr_built                 NaN    NaN       1.0           NaN      NaN  NaN
# yr_renovated             NaN    NaN       NaN           1.0      NaN  NaN
# zipcode                  NaN    NaN       NaN           NaN      1.0  NaN
# lat                      NaN    NaN       NaN           NaN      NaN  1.0
# long                     NaN    NaN       NaN           NaN      NaN  NaN
# log_price                NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_above           NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_basement        NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_living          NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_living15        NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_lot             NaN    NaN       NaN           NaN      NaN  NaN
# log_sqft_lot15           NaN    NaN       NaN           NaN      NaN  NaN
#
#                    long  log_price  log_sqft_above  log_sqft_basement  \
# id                  NaN        NaN             NaN                NaN
# bedrooms            NaN        NaN             NaN                NaN
# bathrooms           NaN        NaN             NaN                NaN
# floors              NaN        NaN             NaN                NaN
# waterfront          NaN        NaN             NaN                NaN
# view                NaN        NaN             NaN                NaN
# condition           NaN        NaN             NaN                NaN
# grade               NaN        NaN             NaN                NaN
# yr_built            NaN        NaN             NaN                NaN
# yr_renovated        NaN        NaN             NaN                NaN
# zipcode             NaN        NaN             NaN                NaN
# lat                 NaN        NaN             NaN                NaN
# long                1.0        NaN             NaN                NaN
# log_price           NaN        1.0             NaN                NaN
# log_sqft_above      NaN        NaN        1.000000                NaN
# log_sqft_basement   NaN        NaN             NaN                1.0
# log_sqft_living     NaN        NaN        0.864979                NaN
# log_sqft_living15   NaN        NaN             NaN                NaN
# log_sqft_lot        NaN        NaN             NaN                NaN
# log_sqft_lot15      NaN        NaN             NaN                NaN
#
#                    log_sqft_living  log_sqft_living15  log_sqft_lot  \
# id                             NaN                NaN           NaN
# bedrooms                       NaN                NaN           NaN
# bathrooms                      NaN                NaN           NaN
# floors                         NaN                NaN           NaN
# waterfront                     NaN                NaN           NaN
# view                           NaN                NaN           NaN
# condition                      NaN                NaN           NaN
# grade                          NaN                NaN           NaN
# yr_built                       NaN                NaN           NaN
# yr_renovated                   NaN                NaN           NaN
# zipcode                        NaN                NaN           NaN
# lat                            NaN                NaN           NaN
# long                           NaN                NaN           NaN
# log_price                      NaN                NaN           NaN
# log_sqft_above            0.864979                NaN           NaN
# log_sqft_basement              NaN                NaN           NaN
# log_sqft_living           1.000000                NaN           NaN
# log_sqft_living15              NaN                1.0           NaN
# log_sqft_lot                   NaN                NaN      1.000000
# log_sqft_lot15                 NaN                NaN      0.918665
#
#                    log_sqft_lot15
# id                            NaN
# bedrooms                      NaN
# bathrooms                     NaN
# floors                        NaN
# waterfront                    NaN
# view                          NaN
# condition                     NaN
# grade                         NaN
# yr_built                      NaN
# yr_renovated                  NaN
# zipcode                       NaN
# lat                           NaN
# long                          NaN
# log_price                     NaN
# log_sqft_above                NaN
# log_sqft_basement             NaN
# log_sqft_living               NaN
# log_sqft_living15             NaN
# log_sqft_lot             0.918665
# log_sqft_lot15           1.000000

# %%
f.jarque_bera('log_price', df)
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id                   21597 non-null int64
# date                 21597 non-null object
# bedrooms             21597 non-null int64
# bathrooms            21597 non-null float64
# floors               21597 non-null float64
# waterfront           21597 non-null float64
# view                 21534 non-null float64
# condition            21597 non-null int64
# grade                21597 non-null int64
# yr_built             21597 non-null int64
# yr_renovated         744 non-null float64
# zipcode              21597 non-null int64
# lat                  21597 non-null float64
# long                 21597 non-null float64
# log_price            21597 non-null float64
# log_sqft_above       21597 non-null float64
# log_sqft_basement    21597 non-null float64
# log_sqft_living      21597 non-null float64
# log_sqft_living15    21597 non-null float64
# log_sqft_lot         21597 non-null float64
# log_sqft_lot15       21597 non-null float64
# dtypes: float64(14), int64(6), object(1)
# memory usage: 3.5+ MB

# %%
from sklearn.feature_selection import RFE 
from sklearn.linear_model import LinearRegression

predictors = df[['bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15']]


linreg = LinearRegression()
selector = RFE(linreg, n_features_to_select = 3)
selector = selector.fit(predictors, df['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6dd5a717ac0f> in <module>
#       2 from sklearn.linear_model import LinearRegression
#       3
# ----> 4 predictors = df[['bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15']]
#       5
#       6
#
# NameError: name 'df' is not defined

# %%
selector.support_
