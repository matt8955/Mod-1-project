# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.head(50)
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  10/13/2014   221900.0         3       1.00         1180
# 1   6414100192   12/9/2014   538000.0         3       2.25         2570
# 2   5631500400   2/25/2015   180000.0         2       1.00          770
# 3   2487200875   12/9/2014   604000.0         4       3.00         1960
# 4   1954400510   2/18/2015   510000.0         3       2.00         1680
# 5   7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6   1321400060   6/27/2014   257500.0         3       2.25         1715
# 7   2008000270   1/15/2015   291850.0         3       1.50         1060
# 8   2414600126   4/15/2015   229500.0         3       1.00         1780
# 9   3793500160   3/12/2015   323000.0         3       2.50         1890
# 10  1736800520    4/3/2015   662500.0         3       2.50         3560
# 11  9212900260   5/27/2014   468000.0         2       1.00         1160
# ...

# %%
sns.heatmap(abs(df.corr()), cmap = 'BuPu', linewidths=.5)

# %%
df.corr()[abs(df.corr()>.75)] # find all highly autocorrelated values
# Out:
#                 id  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id             1.0    NaN       NaN        NaN          NaN       NaN     NaN
# price          NaN    1.0       NaN        NaN          NaN       NaN     NaN
# bedrooms       NaN    NaN       1.0        NaN          NaN       NaN     NaN
# bathrooms      NaN    NaN       NaN   1.000000     0.755758       NaN     NaN
# sqft_living    NaN    NaN       NaN   0.755758     1.000000       NaN     NaN
# sqft_lot       NaN    NaN       NaN        NaN          NaN       1.0     NaN
# floors         NaN    NaN       NaN        NaN          NaN       NaN     1.0
# waterfront     NaN    NaN       NaN        NaN          NaN       NaN     NaN
# view           NaN    NaN       NaN        NaN          NaN       NaN     NaN
# condition      NaN    NaN       NaN        NaN          NaN       NaN     NaN
# grade          NaN    NaN       NaN        NaN     0.762779       NaN     NaN
# ...

# %%
x_cols = ['bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated','sqft_living15', 'sqft_lot15']

# %%
cols = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
pd.plotting.scatter_matrix(df[cols], figsize=(10,12));
.493 + sqft living + broom
.53 + view
.593 + condition
# Out:
#   File "<ipython-input-10-4836f06b58a0>", line 3
#     .493 + sqft living + broom
#                      ^
# SyntaxError: invalid syntax

# %%
df.zipcode.plot.kde()

# %%
k = len(df.columns)
n = 2
m = (k - 1) // n + 1
fig, axes = plt.subplots(m, n, figsize=(n * 5, m * 3))
for i, (name, col) in enumerate(df.iteritems()):
    r, c = i // n, i % n
    ax = axes[r, c]
    col.hist(ax=ax)
    ax2 = col.plot.kde(ax=ax, secondary_y=True, title=name)
    ax2.set_ylim(0)
fig.tight_layout()

# %%
df.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
df['age_house'] = 2020 - df.yr_built

# %%
df['price'] = np.log(df.price)

# %%
df.sqft_above = np.log(df.sqft_above)
df.sqft_living15 = np.log(df.sqft_living15)

# %%
model = ols(formula='price ~ bathrooms + sqft_living + grade + sqft_above + sqft_living15 + view', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     5010.
# Date:                Tue, 18 Jun 2019   Prob (F-statistic):               0.00
# Time:                        17:54:59   Log-Likelihood:                -7323.0
# No. Observations:               21534   AIC:                         1.466e+04
# Df Residuals:                   21527   BIC:                         1.472e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
